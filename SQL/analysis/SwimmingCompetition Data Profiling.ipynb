# %%
import pandas as pd
import numpy as np
#from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-4c9aff3ca463> in <module>()
#       2 import numpy as np
#       3 #from matplotlib import pyplot as plt
# ----> 4 get_ipython().run_line_magic('matplotlib', 'inline')
#
# c:\users\timofeygavrilenko\azuredatastudio-python\0.0.1\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2129                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2130             with self.builtin_trap:
# -> 2131                 result = fn(*args,**kwargs)
#    2132             return result
#    2133
#
# <c:\users\timofeygavrilenko\azuredatastudio-python\0.0.1\lib\site-packages\decorator.py:decorator-gen-108> in matplotlib(self, line)
#
# c:\users\timofeygavrilenko\azuredatastudio-python\0.0.1\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
# ...

# %%
# !pip install matplotlib
